# %% [markdown]
# <a href="https://colab.research.google.com/github/janeaf/Extraccion-de-conocimientos-de-bases-de-datos/blob/main/2_2_Preparaci%C3%B3n_de_los_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![portada.png](data:image/png;base64,...)

# %% [markdown]
# # INTRODUCCION
# Este conjunto de datos tiene datos de clientes que compran ropa en línea. La tienda ofrece sesiones de consejos de estilo y ropa en la tienda. Los clientes entran a la tienda, tienen sesiones / reuniones con un estilista personal, luego pueden ir a casa y ordenar en una aplicación móvil o sitio web la ropa que desean.
#
# La compañía está tratando de decidir si enfocar sus esfuerzos en su experiencia con la aplicación móvil o en su sitio web.

# %% [markdown]
# # Importación de librerias

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Recuperación de los datos
# Se va a trabajar con un archivo csv de clientes de comercio electrónico de la compañía.
# Contiene la información del Cliente. Como: Correo electrónico,
# Dirección y color.

# %%
from google.colab import files 
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-acd5a5fa-8ef6-4033-880f-cbadee4e4850" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acd5a5fa-8ef6-4033-880f-cbadee4e4850">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
clientes = pd.read_csv('ecommerce_customers.csv')

# %%
clientes.head(8)
# Out:
#                            Email  ... Yearly Amount Spent
# 0      mstephenson@fernandez.com  ...          587.951054
# 1              hduke@hotmail.com  ...          392.204933
# 2               pallen@yahoo.com  ...          487.547505
# 3        riverarebecca@gmail.com  ...          581.852344
# 4  mstephens@davidson-herman.com  ...          599.406092
# 5         alvareznancy@lucas.biz  ...          637.102448
# 6          katherine20@yahoo.com  ...          521.572175
# 7             awatkins@yahoo.com  ...          549.904146
#
# [8 rows x 8 columns]

# %%
clientes.describe()
# Out:
#        Avg. Session Length  ...  Yearly Amount Spent
# count           500.000000  ...           500.000000
# mean             33.053194  ...           499.314038
# std               0.992563  ...            79.314782
# min              29.532429  ...           256.670582
# 25%              32.341822  ...           445.038277
# 50%              33.082008  ...           498.887875
# 75%              33.711985  ...           549.313828
# max              36.139662  ...           765.518462
#
# [8 rows x 5 columns]

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       499 non-null    float64
#  6   Length of Membership  499 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# # Análisis de datos exploratorios
# Gráfico conjunto a la comparación de columnas en Time on Website y Yearly Amount Spent.

# %%
from scipy.stats import pearsonr

# %% [markdown]
# ## Time on Website

# %%
sns.jointplot(x="Time on Website", y="Yearly Amount Spent", data=clientes, color='purple')

# %% [markdown]
# ## Time App

# %%
sns.jointplot(x="Time on App", y="Yearly Amount Spent", data=clientes, color='purple')

# %% [markdown]
# Se utilizo el Jointplot donde crea una gráfica en 2D en hex bin donde se compara Time on App y Length of Membership.

# %%
sns.jointplot(x="Time on App", y="Length of Membership", data=clientes, kind="hex", color="purple")

# %%
sns.pairplot(clientes)

# %% [markdown]
# Se encontro la relación en el Lenght of Membership ya que
# dispersa.
#
# Diagrama de Modelo de Lineal
#
# Yearly Amount Spent vs. Length of Membership.

# %%
sns.regplot(x="Length of Membership", y="Yearly Amount Spent", data=clientes, color='purple')
